# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashankPandey2111/Stock_prediction/blob/main/Stock_Predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt

start = dt.datetime(2000,1,1)
end = dt.datetime.now( )

stock ="POWERGRID.NS"
df=yf.download(stock , start , end)
# Out:
# /tmp/ipython-input-250433484.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df=yf.download(stock , start , end)
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    31.243086    34.007137    25.823683    27.888958    855215656
# 2007-10-08    29.643658    32.299009    29.457316    32.299009    126671715
# 2007-10-09    31.662338    31.941848    28.059757    29.659178    116725709
# 2007-10-10    31.957390    32.609582    31.677880    32.485354     67931378
# 2007-10-11    35.528912    37.268090    31.677877    37.268090    106320954

# %%
df.shape
# Out:
# (4475, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1465 entries, 2020-01-01 to 2025-11-27
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   1465 non-null   float64
#  1   (High, POWERGRID.NS)    1465 non-null   float64
#  2   (Low, POWERGRID.NS)     1465 non-null   float64
#  3   (Open, POWERGRID.NS)    1465 non-null   float64
#  4   (Volume, POWERGRID.NS)  1465 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 68.7 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4476.000000  4476.000000  4476.000000  4476.000000  4.476000e+03
# mean      89.500852    90.632022    88.393750    89.547974  1.193651e+07
# std       78.482947    79.361544    77.598307    78.498303  2.005475e+07
# min       18.241360    19.499384    16.354323    19.405032  0.000000e+00
# 25%       35.470576    36.058898    35.030290    35.541071  4.950986e+06
# 50%       64.997253    65.947807    64.154865    65.046061  8.579202e+06
# 75%      100.235586   101.571171    98.834314   100.387987  1.381271e+07
# max      348.714539   349.477891   340.842340   347.378627  8.552157e+08

# %%
df = df.reset_index()

# %%
df.head( )
# Out:
# Price        Date        Close         High          Low         Open  \
# Ticker            POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0      2007-10-05    31.243086    34.007137    25.823683    27.888958
# 1      2007-10-08    29.643658    32.299009    29.457316    32.299009
# 2      2007-10-09    31.662338    31.941848    28.059757    29.659178
# 3      2007-10-10    31.957390    32.609582    31.677880    32.485354
# 4      2007-10-11    35.528912    37.268090    31.677877    37.268090
#
# Price        Volume
# Ticker POWERGRID.NS
# 0         855215656
# 1         126671715
# 2         116725709
# 3          67931378
# 4         106320954

# %%
df.columns
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv("powergrid.csv")
data1 = pd.read_csv("powergrid.csv")

# %%
data1.head()
# Out:
#     Price        Date               Close                High  \
# 0  Ticker         NaN        POWERGRID.NS        POWERGRID.NS
# 1       0  2007-10-05  31.243085861206055  34.007136830991804
# 2       1  2007-10-08  29.643657684326172  32.299008600809344
# 3       2  2007-10-09  31.662338256835938  31.941847931563615
# 4       3  2007-10-10   31.95738983154297  32.609582148487036
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1   25.82368334804961   27.88895770674675     855215656
# 2  29.457316456226895  32.299008600809344     126671715
# 3  28.059757414963062  29.659177865334932     116725709
# 4  31.677880042092518  32.485353937265906      67931378

# %%
#candlestick
import plotly.graph_objects as go
fig = go.Figure(data=[go.Candlestick(x=data1['Date'],
                open=data1['Open'],
                high=data1['High'],
                low=data1['Low'],
                close=data1['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d0aaad94-afc9-454c-8bdf-3f0b50dd6038" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d